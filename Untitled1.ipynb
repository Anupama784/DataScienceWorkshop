# %% [markdown]
# <a href="https://colab.research.google.com/github/Anupama784/DataScienceWorkshop/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


emp= pd.DataFrame({"NAME":["Steve","Lia","Vin","Katie"],"Age":[32,28,45,38],"Gender":["male","female","male","female"],"Rating":[3.45,4.6,3.9,2.78]})
display(emp.head())
# Out:
#     NAME  Age  Gender  Rating
# 0  Steve   32    male    3.45
# 1    Lia   28  female    4.60
# 2    Vin   45    male    3.90
# 3  Katie   38  female    2.78

# %%
#print the column names
emp.columns
# Out:
# Index(['NAME', 'Age', 'Gender', 'Rating'], dtype='object')

# %%
#print the dimensiuon of the data set
emp.shape
# Out:
# (4, 4)

# %%
#print only the number of rows
emp.shape[0]
# Out:
# 4

# %%
#print the no of columns
emp.shape[1]
# Out:
# 4

# %%
len(emp.columns)
# Out:
# 4

# %%
#print the data types of the data frames
emp.dtypes
# Out:
# NAME       object
# Age         int64
# Gender     object
# Rating    float64
# dtype: object

# %%
#seperate the numerical and categorical variables
cat_df=emp.select_dtypes(include="object")
cat_df
# Out:
#    Age  Rating
# 0   32    3.45
# 1   28    4.60
# 2   45    3.90
# 3   38    2.78

# %%
#create a data frame with numeric variables
num_df = emp.select_dtypes(include="number")
num_df
# Out:
#    Age  Rating
# 0   32    3.45
# 1   28    4.60
# 2   45    3.90
# 3   38    2.78

# %%
emp.empty
# Out:
# False

# %%
#transposition
print(emp.T)
# Out:
#             0       1     2       3
# NAME    Steve     Lia   Vin   Katie
# Age        32      28    45      38
# Gender   male  female  male  female
# Rating   3.45     4.6   3.9    2.78

# %%
type(emp["NAME"])
# Out:
# pandas.core.series.Series

# %%
#PRINT NAME AND GENDER
emp[["NAME","Gender"]]
# Out:
#     NAME  Gender
# 0  Steve    male
# 1    Lia  female
# 2    Vin    male
# 3  Katie  female

# %%
#print the first two rows
emp.head(2)
# Out:
#     NAME  Age  Gender  Rating
# 0  Steve   32    male    3.45
# 1    Lia   28  female    4.60

# %%
#print the last two rows
emp.tail(2)
# Out:
#     NAME  Age  Gender  Rating
# 2    Vin   45    male    3.90
# 3  Katie   38  female    2.78

# %%
#print the records for row 1 and 2
emp.iloc[1:3,:]
# Out:
#   NAME  Age  Gender  Rating
# 1  Lia   28  female     4.6
# 2  Vin   45    male     3.9

# %%
#print row number 1,2,3 and clumns name and age
emp.iloc[1:4,0:2]
# Out:
#     NAME  Age
# 1    Lia   28
# 2    Vin   45
# 3  Katie   38

# %%
#for row 2 and 3 print gender and rating
emp.iloc[2:4,2:4]
# Out:
#    Gender  Rating
# 2    male    3.90
# 3  female    2.78

# %%
#print gender aaand rating of row 0,2,3
emp.iloc[[0,2,3],:2:4]
# Out:
#     NAME
# 0  Steve
# 2    Vin
# 3  Katie

# %%
emp.loc[[0,2,3],["Gender"]]
# Out:
#    Gender
# 0    male
# 2    male
# 3  female

# %%
#print the record of male employees
emp[emp["Gender"]=="male"]
# Out:
#     NAME  Age Gender  Rating
# 0  Steve   32   male    3.45
# 2    Vin   45   male    3.90

# %%
emp[emp["Rating"]>=4]
# Out:
#   NAME  Age  Gender  Rating
# 1  Lia   28  female     4.6

# %%
emp[emp.Age.between(35,45)]
# Out:
#     NAME  Age  Gender  Rating
# 2    Vin   45    male    3.90
# 3  Katie   38  female    2.78

# %%
emp[(emp.Age>=35)&(emp.Age<=45)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-875/241724186.py in <cell line: 0>()
# ----> 1 emp[(emp.Age>=35)&(emp.Age<=45)]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Age'

# %%
emp1 = emp.sort_values(by="Age")
display(emp1 )
# Out:
#     NAME  Age  Gender  Rating
# 1    Lia   28  female    4.60
# 0  Steve   32    male    3.45
# 3  Katie   38  female    2.78
# 2    Vin   45    male    3.90

# %%
#drop a column
emp2=emp.drop("Rating",axis=1)
display(emp2)
# Out:
#     NAME  Age  Gender
# 0  Steve   32    male
# 1    Lia   28  female
# 2    Vin   45    male
# 3  Katie   38  female

# %%
#to drop rows
emp2.drop([0],axis =0)
# Out:
#     NAME  Age  Gender
# 1    Lia   28  female
# 2    Vin   45    male
# 3  Katie   38  female

# %%
columns_to_drop = ["Age", "Rating"]
existing_columns = [col for col in columns_to_drop if col in emp.columns]

if existing_columns:
    emp.drop(existing_columns, axis=1, inplace=True)
    print(f"Dropped columns: {existing_columns}")
else:
    print("Columns 'Age' and 'Rating' were not found or already dropped.")
emp
# Out:
# Columns 'Age' and 'Rating' were not found or already dropped.
#     NAME  Gender
# 0  Steve    male
# 1    Lia  female
# 2    Vin    male
# 3  Katie  female

# %%
df=pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='object')
